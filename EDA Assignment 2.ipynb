# %%
Q1. Load the flight price dataset and examine its dimensions. How many rows and columns does the
dataset have?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_excel('flight_price.xlsx')

# %%
df.shape
# Out:
# (10683, 11)

# %%
A1. The dataset has 10683 rows and 11 columns

# %%
Q2. What is the distribution of flight prices in the dataset? Create a histogram to visualize the
distribution.

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
sns.histplot(df['Price'],kde=True)
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Count'>

# %%
A2. The distribution of flight prices is right skewed.

# %%
Q3. What is the range of prices in the dataset? What is the minimum and maximum price?

# %%
df['Price'].describe()
# Out:
# count    10683.000000
# mean      9087.064121
# std       4611.359167
# min       1759.000000
# 25%       5277.000000
# 50%       8372.000000
# 75%      12373.000000
# max      79512.000000
# Name: Price, dtype: float64

# %%
A3. The maximum price is 79512 and minimum price is 1759 with the range being 77753.

# %%
Q4. How does the price of flights vary by airline? Create a boxplot to compare the prices of different
airlines.

# %%
sns.boxplot(data=df,x='Price',y='Airline')
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Airline'>

# %%
Q5. Are there any outliers in the dataset? Identify any potential outliers using a boxplot and describe how
they may impact your analysis.

# %%
sns.boxplot(df['Price'])
# Out:
# <AxesSubplot: >

# %%
A5. Yes, there are so many outliers in the price column. They may impact the average price cost of a economy
    or business class.

# %%
Q6. You are working for a travel agency, and your boss has asked you to analyze the Flight Price dataset
to identify the peak travel season. What features would you analyze to identify the peak season, and how
would you present your findings to your boss?

# %%
A6. First I would look at the date of journey. I would extract the travel month data of the flight. Then I 
    would plot a histogram between travel month and number of flights. I got 5 and 6 that is May and June as
    peak season for travel.

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662

# %%
df['Travel month']=df['Date_of_Journey'].str.split('/').str[1]

# %%
sns.histplot(data=df,x='Travel month',color='r')
# Out:
# <AxesSubplot: xlabel='Travel month', ylabel='Count'>

# %%
Q7. You are a data analyst for a flight booking website, and you have been asked to analyze the Flight
Price dataset to identify any trends in flight prices. What features would you analyze to identify these
trends, and what visualizations would you use to present your findings to your team?

# %%
A7. I would use the travel hours, travelling month, destination, Total stops, airline preference as the 
    features. Based on the below visualisations, I would present that:
        Most people like to travel to cochin, then bangalore.
        Most people travel during the months may and june.
        The most used airways are jet airways and least is trujet.
        Most people tend to travel with the flights having one stop.
        Most people are travelling in 1 hour to cochin which means many are in south India.

# %%
df['Travel hour']=df['Duration'].str.split(' ').str[0].str[0]

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
#
#   Travel month Travel hour
# 0           03           2
# 1           05           7

# %%
fig,axis=plt.subplots(3,2,figsize=(15,20))
plt.subplot(3,2,1)
sns.histplot(data=df,x='Destination')
plt.subplot(3,2,2)
sns.histplot(data=df,x='Travel month')
plt.subplot(3,2,3)
sns.histplot(data=df,x='Destination',hue='Airline')
plt.subplot(3,2,4)
sns.histplot(data=df,x='Total_Stops',hue='Airline')
plt.subplot(3,2,5)
sns.histplot(data=df,x='Travel hour',hue='Destination')
plt.subplot(3,2,6)
sns.histplot(data=df,y='Airline')
# Out:
# <AxesSubplot: xlabel='Count', ylabel='Airline'>

# %%
Q8. You are a data scientist working for an airline company, and you have been asked to analyze the
Flight Price dataset to identify the factors that affect flight prices. What features would you analyze to
identify these factors, and how would you present your findings to the management team?

# %%
A8. I would use destination, total stops, airline features to analyze the price factors. Based on below 
    visualizations I would present that:
        Mostly delhi travelling people are paying high price flights.
        1 stop flights are high priced.
        Jet airways business costs high.

# %%
df.head(2)
# Out:
#      Airline Date_of_Journey    Source Destination                  Route  \
# 0     IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1  Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
#
#   Travel month Travel hour
# 0           03           2
# 1           05           7

# %%
sns.histplot(data=df,x='Price',y='Destination')
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Destination'>

# %%
sns.histplot(data=df,x='Price',y='Total_Stops')
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Total_Stops'>

# %%
sns.histplot(data=df,x='Price',y='Airline')
# Out:
# <AxesSubplot: xlabel='Price', ylabel='Airline'>

# %%
Q9. Load the Google Playstore dataset and examine its dimensions. How many rows and columns does
the dataset have?

# %%
df=pd.read_csv('https://raw.githubusercontent.com/krishnaik06/playstore-Dataset/main/googleplaystore.csv')

# %%
df.shape
# Out:
# (10841, 13)

# %%
A9. The dataset has 10841 rows and 13 columns.

# %%
Q10. How does the rating of apps vary by category? Create a boxplot to compare the ratings of different
app categories.

# %%
A10. Based on the below visualisation, family, game, shopping, lifestyle have a rating from 3.5 to 5.
     The least ratings are given to tools, finance, business.

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10841 entries, 0 to 10840
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             10841 non-null  object
#  1   Category        10841 non-null  object
#  2   Rating          9367 non-null   float64
#  3   Reviews         10841 non-null  object
#  4   Size            10841 non-null  object
#  5   Installs        10841 non-null  object
#  6   Type            10840 non-null  object
#  7   Price           10841 non-null  object
#  8   Content Rating  10840 non-null  object
#  9   Genres          10841 non-null  object
#  10  Last Updated    10841 non-null  object
#  11  Current Ver     10833 non-null  object
#  12  Android Ver     10838 non-null  object
# dtypes: float64(1), object(12)
# memory usage: 1.1+ MB

# %%
df=df[df['Rating']!=19.0]

# %%
df['Rating'].max()
# Out:
# 5.0

# %%
sns.histplot(data=df,x='Rating',hue='Category',kde=True)
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Count'>

# %%
sns.boxplot(data=df,x='Rating',y='Category')
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Category'>

# %%
Q11. Are there any missing values in the dataset? Identify any missing values and describe how they may
impact your analysis.

# %%
df.isnull().sum()
# Out:
# App                  0
# Category             0
# Rating            1474
# Reviews              0
# Size                 0
# Installs             0
# Type                 1
# Price                0
# Content Rating       1
# Genres               0
# Last Updated         0
# Current Ver          8
# Android Ver          3
# dtype: int64

# %%
A11. Yes there are many missing values in the dataset. The column rating, type, content rating, current version
     and android version have missing values. 
     Missing values lead to biased results, they reduce the sample size and impact the statistical power of
     analysis and lead to unreliable conclusions. 
     They can affect the model and the results maybe incorrect.

# %%
Q12. What is the relationship between the size of an app and its rating? Create a scatter plot to visualize
the relationship.

# %%
A12. Based on the below visualisations, they are directly related.

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews Size  Installs  Type Price Content Rating  \
# 0     159  19M   10,000+  Free     0       Everyone
# 1     967  14M  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df['Size']=df['Size'].str.replace('M','000')
df['Size']=df['Size'].str.replace('k','')
df['Size']=df['Size'].str.replace('K','')

# %%
sns.scatterplot(data=df,x='Rating',y='Size')
# Out:
# <AxesSubplot: xlabel='Rating', ylabel='Size'>

# %%
df=df[df['Size']!='Varies with device']

# %%
df['Size'].unique()
# Out:
# array(['19000', '14000', '8.7000', '25000', '2.8000', '5.6000', '29000',
#        '33000', '3.1000', '28000', '12000', '20000', '21000', '37000',
#        '2.7000', '5.5000', '17000', '39000', '31000', '4.2000', '7.0000',
#        '23000', '6.0000', '6.1000', '4.6000', '9.2000', '5.2000', '11000',
#        '24000', '9.4000', '15000', '10000', '1.2000', '26000', '8.0000',
#        '7.9000', '56000', '57000', '35000', '54000', '201', '3.6000',
#        '5.7000', '8.6000', '2.4000', '27000', '2.5000', '16000', '3.4000',
#        '8.9000', '3.9000', '2.9000', '38000', '32000', '5.4000', '18000',
#        '1.1000', '2.2000', '4.5000', '9.8000', '52000', '9.0000',
#        '6.7000', '30000', '2.6000', '7.1000', '3.7000', '22000', '7.4000',
#        '6.4000', '3.2000', '8.2000', '9.9000', '4.9000', '9.5000',
#        '5.0000', '5.9000', '13000', '73000', '6.8000', '3.5000', '4.0000',
#        '2.3000', '7.2000', '2.1000', '42000', '7.3000', '9.1000', '55000',
# ...

# %%
df=df[df['Size']!='1,000+']

# %%
df['Size']=df['Size'].astype(float)

# %%
df['Size']
# Out:
# 0        19000.0
# 1        14000.0
# 2            8.7
# 3        25000.0
# 4            2.8
#           ...
# 10835        9.6
# 10836    53000.0
# 10837        3.6
# 10838        9.5
# 10840    19000.0
# Name: Size, Length: 9145, dtype: float64

# %%
Q13. How does the type of app affect its price? Create a bar chart to compare average prices by app type.

# %%
A13. Based on the below visualisations, mostly free apps are downloaded than paid. Family category has the most
     number of free apps and also paid apps.

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews     Size  Installs  Type Price Content Rating  \
# 0     159  19000.0   10,000+  Free     0       Everyone
# 1     967  14000.0  500,000+  Free     0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df['Price']=df['Price'].str.replace('$','')

# %%
df['Price']
# Out:
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 10835    0
# 10836    0
# 10837    0
# 10838    0
# 10840    0
# Name: Price, Length: 9145, dtype: object

# %%
df['Price']=df['Price'].astype(float)

# %%
sns.histplot(data=df,hue='Type',y='Category')
# Out:
# <AxesSubplot: xlabel='Count', ylabel='Category'>

# %%
Q14. What are the top 10 most popular apps in the dataset? Create a frequency table to identify the apps
with the highest number of installs.

# %%
A14. Based on below findings, the top 10 apps are:
    'Google News',
    'Subway Surfers',
    'SHAREit - Transfer & Share',
    'Dropbox',
    'imo free video calls and chat',
    'Samsung Health',
    'Temple Run 2',
    'Candy Crush Saga',
    'Pou',
    'UC Browser - Fast Download Private & Secure'
    and the frequency table is

# %%
frequency_table
# Out:
# ['Google News',
#  'Subway Surfers',
#  'SHAREit - Transfer & Share',
#  'Dropbox',
#  'imo free video calls and chat',
#  'Samsung Health',
#  'Temple Run 2',
#  'Candy Crush Saga',
#  'Pou',
#  'UC Browser - Fast Download Private & Secure',
#  'Angry Birds Rio',
#  'Smash Hit',
#  'Temple Run',
#  'Plants vs. Zombies FREE',
#  'Angry Birds 2',
#  'BeautyPlus - Easy Photo Editor & Selfie Camera',
#  'Bus Rush: Subway Edition',
#  'Talking Tom & Ben News',
#  '8 Ball Pool',
#  'Dream League Soccer 2018',
#  'Angry Birds Star Wars',
#  'ROBLOX',
#  '3D Bowling',
#  'Ant Smasher by Best Cool & Fun Games',
#  'Z Camera - Photo Editor, Beauty Selfie, Collage',
#  'ES File Explorer File Manager',
#  'Garena Free Fire',
#  'Dr. Driving',
#  'Avast Mobile Security 2018 - Antivirus & App Lock',
#  'Score! Hero',
#  'Banana Kong',
#  'Clash Royale',
#  'Microsoft Outlook',
#  'WPS Office - Word, Docs, PDF, Note, Slide & Sheet',
#  'Google Now Launcher',
#  'Jetpack Joyride',
#  'Skater Boy',
# ...

# %%
df.head(2)
# Out:
#                                               App        Category  Rating  \
# 0  Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                             Coloring book moana  ART_AND_DESIGN     3.9
#
#   Reviews     Size  Installs  Type  Price Content Rating  \
# 0     159  19000.0   10,000+  Free    0.0       Everyone
# 1     967  14000.0  500,000+  Free    0.0       Everyone
#
#                       Genres      Last Updated Current Ver   Android Ver
# 0               Art & Design   January 7, 2018       1.0.0  4.0.3 and up
# 1  Art & Design;Pretend Play  January 15, 2018       2.0.0  4.0.3 and up

# %%
df['Installs']=df['Installs'].str.replace(',','')
df['Installs']=df['Installs'].str.replace('+','')

# %%
df['Installs']=df['Installs'].astype(int)

# %%
df.sort_values(by='Installs',ascending=False,inplace=True)
df.head(2)
# Out:
#                  App            Category  Rating   Reviews     Size  \
# 1917  Subway Surfers                GAME     4.5  27725352  76000.0
# 3736     Google News  NEWS_AND_MAGAZINES     3.9    877635  13000.0
#
#         Installs  Type  Price Content Rating            Genres  \
# 1917  1000000000  Free    0.0   Everyone 10+            Arcade
# 3736  1000000000  Free    0.0           Teen  News & Magazines
#
#         Last Updated Current Ver Android Ver
# 1917   July 12, 2018      1.90.0  4.1 and up
# 3736  August 1, 2018       5.2.0  4.4 and up

# %%
df['App'].duplicated()
# Out:
# 3816    False
# 3736     True
# 1872    False
# 1654     True
# 1917     True
#         ...
# 8081    False
# 5486    False
# 5945    False
# 7434    False
# 4465    False
# Name: App, Length: 9145, dtype: bool

# %%
df.drop_duplicates(subset='App',inplace=True)

# %%
top_10apps=list(df.head(10)['App'])

# %%
top_10apps
# Out:
# ['Google News',
#  'Subway Surfers',
#  'SHAREit - Transfer & Share',
#  'Dropbox',
#  'imo free video calls and chat',
#  'Samsung Health',
#  'Temple Run 2',
#  'Candy Crush Saga',
#  'Pou',
#  'UC Browser - Fast Download Private & Secure']

# %%
frequency_table=list(df['App'])

# %%
df_appSorted=df

# %%
Q15. A company wants to launch a new app on the Google Playstore and has asked you to analyze the
Google Playstore dataset to identify the most popular app categories. How would you approach this
task, and what features would you analyze to make recommendations to the company?

# %%
A15. The programming for this question is done before this question in question 14.
     The approach I followed is:
        First I would use the head() function and look at the dataset. 
        I removed the + and , from installs column.
        I then converted the data into int type.
        I sorted the dataframe in descending order of app downloads.
        I removed the multiple values of same app.
        I finally got a dataframe which had apps based on their downloads.
        Then I would present the most popular apps to the company.

# %%
Q16. A mobile app development company wants to analyze the Google Playstore dataset to identify the
most successful app developers. What features would you analyze to make recommendations to the
company, and what data visualizations would you use to present your findings?

# %%
top_apps=df_appSorted['App'].head(10)

# %%
df_appSorted.head(2)
# Out:
#                  App            Category  Rating   Reviews     Size  \
# 3816     Google News  NEWS_AND_MAGAZINES     3.9    877643  13000.0
# 1872  Subway Surfers                GAME     4.5  27725352  76000.0
#
#         Installs  Type  Price Content Rating            Genres  \
# 3816  1000000000  Free    0.0           Teen  News & Magazines
# 1872  1000000000  Free    0.0   Everyone 10+            Arcade
#
#         Last Updated Current Ver Android Ver
# 3816  August 1, 2018       5.2.0  4.4 and up
# 1872   July 12, 2018      1.90.0  4.1 and up

# %%
A16. The most successfull app developers are the makers of the apps:
     'Google News',
     'Subway Surfers',
     'SHAREit - Transfer & Share',
     'Dropbox',
     'imo free video calls and chat',
     'Samsung Health',
     'Temple Run 2',
     'Candy Crush Saga',
     'Pou',
     'UC Browser - Fast Download Private & Secure'
     I would look at the type and category features first and make a histplot. The histplot tells that
     free apps and family category apps are mostly downloaded.

# %%
sns.histplot(data=df,y='Category',hue='Type')
# Out:
# <AxesSubplot: xlabel='Count', ylabel='Category'>

# %%
Q17. A marketing research firm wants to analyze the Google Playstore dataset to identify the best time to
launch a new app. What features would you analyze to make recommendations to the company, and
what data visualizations would you use to present your findings?

# %%
A17. Based on below visualisation, I would use Month and category feature. The most downloads are in July 
     in the category of Family and genre parent education.

# %%
df['Month']=df['Last Updated'].str.split(' ').str[0]

# %%
df['Day']=df['Last Updated'].str.split(' ').str[1]

# %%
df['Year']=df['Last Updated'].str.split(' ').str[2]

# %%
df[['Day','Month','Year']]
# Out:
#        Day    Month  Year
# 0       7,  January  2018
# 1      15,  January  2018
# 2       1,   August  2018
# 3       8,     June  2018
# 4      20,     June  2018
# ...    ...      ...   ...
# 10836  25,     July  2017
# 10837   6,     July  2018
# 10838  20,  January  2017
# 10839  19,  January  2015
# 10840  25,     July  2018
#
# [10841 rows x 3 columns]

# %%
fig,axis=plt.subplots(1,1,figsize=(10,7))
plt.subplot(1,1,1)
sns.histplot(data=df,x='Month',bins=1)
# Out:
# <AxesSubplot: xlabel='Month', ylabel='Count'>

# %%
sns.
